# %%
# %matplotlib inline

# %% [markdown]
# <div style="direction:rtl"> لكي يعمل الكود الذي في الاسفل يجب أن تكون كلا من بايثون و
#
# PILو numpy منصبة ع جهازك
# <br/>
# https://www.python.org/downloads/<br/>
# https://www.scipy.org/install.html<br/>
# http://www.pythonware.com/products/pil/
# </div>

# %%
#استدعاء مكتبة PIL
#وهي مكتبة متخصصة للمعالجة الصور
from PIL import Image
#استدعاء مكتبة الرسومات matplotlib
from pylab import *

# %% [markdown]
# <div style="direction:rtl">
# المودل Image <br/>
# مسؤول عن قراءة الصور بصيغها المختلفة<br/>
# الناتج من هذا السطر هو كيان من نوع <br/>
# PIL
# </div>

# %%
imag = Image.open("images/eggs.jpg")

# %% [markdown]
# <div style="direction:rtl">
# لتحويل هذه الصورة من ملونة <br/>
# الى grey<br/>
# نستخدم الدالة<br/>
# convert
# </div>

# %%
imag = Image.open("images/eggs.jpg").convert ('L')

# %%
img = array(Image.open("images/eggs.jpg").convert('L'))

# %%
imshow(img)
# some points
x = [100,100,400,400]
y = [200,500,200,500]
# plot the points with red star-markers
plot(x,y,'r*')
# line plot connecting the first two points
plot(x[:2],y[:2])
# add title and show the plot
title('Plotting: "empire.jpg"')
show()
